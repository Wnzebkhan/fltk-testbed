# %%
from pyDOE2 import *

# %%
import pandas as pd
import researchpy as rp
import seaborn as sns
import numpy as np

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

code_size = [ 1772.6298623734556, 355.31202785493844, 357.3969244475313, 360.81213555864207, 384.52922200694474, 1028.4031622339407, 531.7901377567518, 515.1248663059415, 1065.7887002910877, 983.8763168641976, 1146.662154451162, 964.5462041616225, 862.114828006957, 1125.2216951999592, 1077.7760679718856, 61.675717040123445, 227.36199994521604, 332.60640624999996, 350.4508801111109, 343.7810417777776
, 294.1034682192805, 287.88462107537623, 789.7972929256849, 735.5977162686632, 317.91615940605715, 100.93555942877131, 95.94582915345293, 162.24573950500348, 104.61387490682574, 101.15231434150449, 2.818201562499995, 114.86182918595678, 1.4428680933641933, 38.958056019290105, 107.15010177777776, 48.93898489443483
, 7.842206083863809, 179.28922206577937, 39.65974622106483, 117.0777647810571, 86.34678747409092, 84.28189441017727, 146.47272515142436, 107.22649834627879, 281.0822292373048 ]
df_fair_norm = pd.DataFrame({'Code_Size': code_size,
                   'Pipeline': np.repeat(['1', '2', '4'], 15),
                   'groups': np.r_[np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5)]})
print(rp.summary_cont(df_fair_norm.groupby(['Pipeline', 'groups']))['Code_Size'])
model = ols('Code_Size ~ C(Pipeline)*C(groups)', df_fair_norm).fit()
sm.stats.anova_lm(model, typ= 2)
# Out:
#                  N       Mean        SD        SE  95% Conf.   Interval
# Pipeline groups
# 1        2       5   646.1360  629.8383  281.6722  -135.9115  1428.1836
#          4       5   824.9966  276.8521  123.8120   481.2393  1168.7539
#          8       5  1035.2642  119.6775   53.5214   886.6649  1183.8635
# 2        2       5   263.1752  123.3082   55.1451   110.0678   416.2826
#          4       5   485.0599  254.4177  113.7791   169.1585   800.9612
#          8       5   112.9787   27.7139   12.3940    78.5674   147.3900
# 4        2       5    53.0462   55.0741   24.6299   -15.3373   121.4298
#          4       5    78.5616   68.9595   30.8396    -7.0629   164.1861
#          8       5   141.0820   82.1546   36.7407    39.0736   243.0904
#                              sum_sq    df          F        PR(>F)
# C(Pipeline)            4.468019e+06   2.0  34.492884  4.296326e-09
# C(groups)              1.658139e+05   2.0   1.280075  2.903677e-01
# ...

# %%
import pandas as pd
import researchpy as rp
import seaborn as sns
import numpy as np

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

code_size = [ 0.000564134,0.002814428,0.00279801,0.002771525,0.002600583,0.000972381,0.001880441,0.001941277,0.000938272,0.001016388,0.000872096,0.001036757,0.001159938,0.000888714,0.000927837,0.016213837,0.004398272,0.003006557
,0.002853467,0.002908828,0.003400164,0.003473614,0.001266148,0.001359439,0.003145483,0.009907311,0.010422548,0.00616349,0.009558961,0.009886081,0.354836224,0.008706112,0.693064047
,0.025668632,0.009332702,0.020433607,0.127515139,0.00557758,0.025214483,0.008541331,0.011581207,0.011864945,0.00682721,0.009326053,0.003557678 ]
df_fair_div_1 = pd.DataFrame({'Code_Size': code_size,
                   'Pipeline': np.repeat(['1', '2', '4'], 15),
                   'groups': np.r_[np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5)]})
print(rp.summary_cont(df_fair_div_1.groupby(['Pipeline', 'groups']))['Code_Size'])
model = ols('Code_Size ~ C(Pipeline)*C(groups)', df_fair_div_1).fit()
sm.stats.anova_lm(model, typ= 2)
# Out:
#                  N    Mean      SD      SE  95% Conf.  Interval
# Pipeline groups
# 1        2       5  0.0023  0.0010  0.0004     0.0011    0.0035
#          4       5  0.0013  0.0005  0.0002     0.0007    0.0020
#          8       5  0.0010  0.0001  0.0001     0.0008    0.0011
# 2        2       5  0.0059  0.0058  0.0026    -0.0013    0.0131
#          4       5  0.0025  0.0011  0.0005     0.0011    0.0039
#          8       5  0.0092  0.0017  0.0008     0.0071    0.0113
# 4        2       5  0.2183  0.3036  0.1358    -0.1587    0.5953
#          4       5  0.0375  0.0510  0.0228    -0.0259    0.1008
#          8       5  0.0086  0.0035  0.0016     0.0043    0.0130
#                          sum_sq    df         F    PR(>F)
# C(Pipeline)            0.071427   2.0  3.389126  0.044816
# C(groups)              0.043300   2.0  2.054561  0.142912
# C(Pipeline):C(groups)  0.086004   4.0  2.040388  0.109344
# Residual               0.379355  36.0       NaN       NaN

# %%
import pandas as pd
import researchpy as rp
import seaborn as sns
import numpy as np

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

code_size = [0.9829248574209453 ,0.9766389131197093 ,0.9777803799877045 ,0.9802195978094597 ,0.9811287591026345 ,0.9796742583091123 ,0.979765569999708 ,0.9792749999542737 ,0.9790113039285814 ,0.9811418549348186 ,0.9711844361659406 
,0.9605243740689539 ,0.9976253627917957 ,0.9650301222686177 ,0.970562959264405 ,0.9192886456908345 ,0.9205288115327654 ,0.9376553449845563 ,0.934094447327452 ,0.9409008778966008 ,0.9258738167224134 ,0.97140393734732 ,0.9755046353587458 ,0.9300251044638443 ,0.9255759703815689 
,0.9587244922636168 ,0.9776587803431902 ,0.9554459597462888 ,0.9721588733115469 ,0.9594293661310898 ,0.7550074123304676 ,0.8027034533839459 ,0.785206757826824 ,0.7527727563985684 ,0.8100167879127029 ,0.931641545263739 ,0.9024802206231834 ,0.9030585320376758 
,0.9170086676660469 ,0.9049368336170595 ,0.9126626925443874 ,0.9384086641457281 ,0.9492756859060174 ,0.9455232679920075 ,0.9411815125570233  ]
df_ut = pd.DataFrame({'Code_Size': code_size,
                   'Pipeline': np.repeat(['1', '2', '4'], 15),
                   'groups': np.r_[np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5),
                                      np.repeat(['2', '4', '8'],5)]})
print(rp.summary_cont(df_ut.groupby(['Pipeline', 'groups']))['Code_Size'])
model = ols('Code_Size ~ C(Pipeline)*C(groups)', df_ut).fit()
sm.stats.anova_lm(model, typ= 2)
# Out:
#                  N    Mean      SD      SE  95% Conf.  Interval
# Pipeline groups
# 1        2       5  0.9797  0.0025  0.0011     0.9766    0.9829
#          4       5  0.9798  0.0008  0.0004     0.9788    0.9808
#          8       5  0.9730  0.0144  0.0065     0.9550    0.9909
# 2        2       5  0.9305  0.0100  0.0045     0.9181    0.9429
#          4       5  0.9457  0.0255  0.0114     0.9141    0.9773
#          8       5  0.9647  0.0097  0.0043     0.9527    0.9767
# 4        2       5  0.7811  0.0265  0.0118     0.7483    0.8140
#          4       5  0.9118  0.0126  0.0056     0.8962    0.9274
#          8       5  0.9374  0.0144  0.0065     0.9195    0.9553
#                          sum_sq    df           F        PR(>F)
# C(Pipeline)            0.079987   2.0  169.491112  4.800128e-19
# C(groups)              0.031369   2.0   66.470805  8.207023e-13
# C(Pipeline):C(groups)  0.041973   4.0   44.470249  1.877837e-13
# ...
